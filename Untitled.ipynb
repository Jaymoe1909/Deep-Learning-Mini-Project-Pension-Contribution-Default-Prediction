# %%
import pandas as pd
from config import CFG

df = pd.read_csv(CFG.features_csv)
# Point-biserial correlation of each feature with the label
corrs = df.drop(columns=["EMPLOYER ID"]).corr()["DEFAULT_LABEL"].drop("DEFAULT_LABEL")
print(corrs.abs().sort_values(ascending=False))
# Out:
# PAYMENT_RATE              0.597423
# AVG_CONTRIBUTION_RATIO    0.564425
# AVG_PAYMENT_DELAY         0.383023
# AMOUNT_CV                 0.371150
# SANCTION_SEVERITY         0.270730
# EMPLOYER_TENURE           0.106103
# TOTAL_ARREARS             0.094858
# AMOUNT_TREND              0.068164
# MAX_CONSECUTIVE_MISSED         NaN
# Name: DEFAULT_LABEL, dtype: float64
